# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np
print(np.__version__)
# Out:
# 1.19.2

# %%
# 1
sns.set_theme(); np.random.seed(0)

mu, sigma = 0, 0.5  
x = np.random.normal(mu, sigma, (50,30))
ax = sns.distplot(x)

# %%
# 2
samples = np.random.exponential(10, (50,30))
sns.set_theme(); np.random.seed(0)
result = sns.distplot(samples)

# %%
samples = np.random.poisson(10,(50,30))
sns.set_theme(); np.random.seed(0)


result = sns.distplot(samples)
